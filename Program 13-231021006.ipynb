# %%
import pandas as pd
import numpy as np
# import matplotlib.pyplot as plt

# %%
student_data = [
    [100,90,10],
    [90,70,7],
    [120,100,14],
    [80,50,2],
]

# pd.DataFrame(student_data)
df = pd.DataFrame(student_data, columns=['iq','marks','package'], index=['Risma','Maya','Sarah','Dina']) #index = Untuk mengubah nama baris
# df = pd.DataFrame(student_data, columns=['iq','marks','package']
df
# Out:
#         iq  marks  package
# Risma  100     90       10
# Maya    90     70        7
# Sarah  120    100       14
# Dina    80     50        2

# %%
df.columns = ['a','b','c'] # ganti nama kolom
df
# Out:
#          a    b   c
# Risma  100   90  10
# Maya    90   70   7
# Sarah  120  100  14
# Dina    80   50   2

# %%
# using dictionary

student_dict = {
    'iq': [100, 90, 80, 120, 0, 0], 
    'marks': [80, 70, 100, 90, 0, 0], 
    'package': [10, 7, 14, 2, 0, 0],
}

students = pd.DataFrame(student_dict)
students
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2   80    100       14
# 3  120     90        2
# 4    0      0        0
# 5    0      0        0

# %%
students[['iq','package']] # untuk mengambil nilai salah satu kolom
# Out:
#     iq  package
# 0  100       10
# 1   90        7
# 2   80       14
# 3  120        2
# 4    0        0
# 5    0        0

# %%
data_harga = pd.read_csv("ms_harga_harian.csv")
data_harga
# Out:
#         kode_produk          tgl_berlaku kode_cabang  harga_berlaku_cabang  \
# 0      PROD-0000001  2008-01-01 00:00:00  CABANG-039                 10980
# 1      PROD-0000002  2008-01-01 00:00:00  CABANG-039                  4220
# 2      PROD-0000003  2008-01-01 00:00:00  CABANG-039                  6220
# 3      PROD-0000004  2008-01-01 00:00:00  CABANG-039                  8020
# 4      PROD-0000005  2008-01-01 00:00:00  CABANG-039                  7210
# ...             ...                  ...         ...                   ...
# 45013  PROD-0000037  2008-12-31 00:00:00  CABANG-065                  5280
# 45014  PROD-0000038  2008-12-31 00:00:00  CABANG-065                  6270
# 45015  PROD-0000039  2008-12-31 00:00:00  CABANG-065                  5640
# 45016  PROD-0000040  2008-12-31 00:00:00  CABANG-065                 15380
# 45017  PROD-0000041  2008-12-31 00:00:00  CABANG-065                 14450
#
#        modal_cabang  biaya_cabang
# ...

# %%
print(data_harga.shape)
print(data_harga.columns)
# Out:
# (45018, 6)
# Index(['kode_produk', 'tgl_berlaku', 'kode_cabang', 'harga_berlaku_cabang',
#        'modal_cabang', 'biaya_cabang'],
#       dtype='object')

# %%
data_harga.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45018 entries, 0 to 45017
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   kode_produk           45018 non-null  object
#  1   tgl_berlaku           45018 non-null  object
#  2   kode_cabang           45018 non-null  object
#  3   harga_berlaku_cabang  45018 non-null  int64
#  4   modal_cabang          45018 non-null  int64
#  5   biaya_cabang          45018 non-null  int64
# dtypes: int64(3), object(3)
# memory usage: 2.1+ MB

# %%
data_harga.describe()
# Out:
#        harga_berlaku_cabang   modal_cabang  biaya_cabang
# count          45018.000000   45018.000000  45018.000000
# mean           14124.498645   13417.638500    173.067440
# std            19419.009070   18447.355772    293.769638
# min              880.000000     830.000000      0.000000
# 25%             5040.000000    4780.000000     30.000000
# 50%             8140.000000    7740.000000     90.000000
# 75%            14930.000000   14160.000000    190.000000
# max           107720.000000  102690.000000   2610.000000

# %%
data_harga.head() # untuk menampilkan 5 data teratas
# Out:
#     kode_produk          tgl_berlaku kode_cabang  harga_berlaku_cabang  \
# 0  PROD-0000001  2008-01-01 00:00:00  CABANG-039                 10980
# 1  PROD-0000002  2008-01-01 00:00:00  CABANG-039                  4220
# 2  PROD-0000003  2008-01-01 00:00:00  CABANG-039                  6220
# 3  PROD-0000004  2008-01-01 00:00:00  CABANG-039                  8020
# 4  PROD-0000005  2008-01-01 00:00:00  CABANG-039                  7210
#
#    modal_cabang  biaya_cabang
# 0         10380           190
# 1          4040            10
# 2          5900            90
# 3          7620            60
# 4          6860            10

# %%
data_harga.tail() # untuk menampilkan 5 data terbawah
# Out:
#         kode_produk          tgl_berlaku kode_cabang  harga_berlaku_cabang  \
# 45013  PROD-0000037  2008-12-31 00:00:00  CABANG-065                  5280
# 45014  PROD-0000038  2008-12-31 00:00:00  CABANG-065                  6270
# 45015  PROD-0000039  2008-12-31 00:00:00  CABANG-065                  5640
# 45016  PROD-0000040  2008-12-31 00:00:00  CABANG-065                 15380
# 45017  PROD-0000041  2008-12-31 00:00:00  CABANG-065                 14450
#
#        modal_cabang  biaya_cabang
# 45013          5060            70
# 45014          5960            90
# 45015          5350           130
# 45016         14570            80
# 45017         13600            90

# %%
data_harga [2:12:2] # dimulai dari 2 hingga 12 dengan selisih 2
# Out:
#      kode_produk          tgl_berlaku kode_cabang  harga_berlaku_cabang  \
# 2   PROD-0000003  2008-01-01 00:00:00  CABANG-039                  6220
# 4   PROD-0000005  2008-01-01 00:00:00  CABANG-039                  7210
# 6   PROD-0000007  2008-01-01 00:00:00  CABANG-039                  4640
# 8   PROD-0000009  2008-01-01 00:00:00  CABANG-039                  4690
# 10  PROD-0000011  2008-01-01 00:00:00  CABANG-039                  1210
#
#     modal_cabang  biaya_cabang
# 2           5900            90
# 4           6860            10
# 6           4440            20
# 8           4500            80
# 10          1150            30

# %%
df5000 = data_harga[(data_harga['modal_cabang']<5000)] # menampilkan harga modal cabang yang kurang dari 5000
df5000
# Out:
#         kode_produk          tgl_berlaku kode_cabang  harga_berlaku_cabang  \
# 1      PROD-0000002  2008-01-01 00:00:00  CABANG-039                  4220
# 6      PROD-0000007  2008-01-01 00:00:00  CABANG-039                  4640
# 7      PROD-0000008  2008-01-01 00:00:00  CABANG-039                  1060
# 8      PROD-0000009  2008-01-01 00:00:00  CABANG-039                  4690
# 9      PROD-0000010  2008-01-01 00:00:00  CABANG-039                  1100
# ...             ...                  ...         ...                   ...
# 44988  PROD-0000012  2008-12-31 00:00:00  CABANG-065                  3720
# 44993  PROD-0000017  2008-12-31 00:00:00  CABANG-065                  1310
# 45002  PROD-0000026  2008-12-31 00:00:00  CABANG-065                   910
# 45006  PROD-0000030  2008-12-31 00:00:00  CABANG-065                  4240
# 45008  PROD-0000032  2008-12-31 00:00:00  CABANG-065                  5210
#
#        modal_cabang  biaya_cabang
# ...

# %%
# df5000['kode_cabang'].unique() # untuk mengentahui cabang yang memiliki modal cabang yang kurang dari 5000
(df5000['kode_produk'].unique()) # untuk mengentahui cabang yang memiliki modal cabang yang kurang dari 5000
# Out:
# array(['PROD-0000002', 'PROD-0000007', 'PROD-0000008', 'PROD-0000009',
#        'PROD-0000010', 'PROD-0000011', 'PROD-0000012', 'PROD-0000017',
#        'PROD-0000020', 'PROD-0000026', 'PROD-0000030', 'PROD-0000032',
#        'PROD-0000037'], dtype=object)

# %%
data_harga['tambahan_modal'] = data_harga['modal_cabang'] + 5000
data_harga.head()
# Out:
#     kode_produk          tgl_berlaku kode_cabang  harga_berlaku_cabang  \
# 0  PROD-0000001  2008-01-01 00:00:00  CABANG-039                 10980
# 1  PROD-0000002  2008-01-01 00:00:00  CABANG-039                  4220
# 2  PROD-0000003  2008-01-01 00:00:00  CABANG-039                  6220
# 3  PROD-0000004  2008-01-01 00:00:00  CABANG-039                  8020
# 4  PROD-0000005  2008-01-01 00:00:00  CABANG-039                  7210
#
#    modal_cabang  biaya_cabang  tambahan_modal
# 0         10380           190           15380
# 1          4040            10            9040
# 2          5900            90           10900
# 3          7620            60           12620
# 4          6860            10           11860

# %% [markdown]
# $$DATA-PRODUK$$

# %%
data_produk = pd.read_csv("ms_produk.csv")
data_produk
# Out:
#      kode_produk kode_kategori                       nama_produk  unit  \
# 0   PROD-0000001       KTG-003                  bawang merah 1kg     1
# 1   PROD-0000002       KTG-003                 bawang putih 1 kg     1
# 2   PROD-0000003       KTG-003                       buncis 1 kg     1
# 3   PROD-0000004       KTG-003               kacang panjang 1 kg     1
# 4   PROD-0000005       KTG-003                 kacang hijau 1 kg     1
# 5   PROD-0000006       KTG-003                      kentang 1 kg     1
# 6   PROD-0000007       KTG-003                      ketimun 1 kg     1
# 7   PROD-0000008       KTG-003                        kobis 1 kg     1
# 8   PROD-0000009       KTG-003                        tomat 1 kg     1
# 9   PROD-0000010       KTG-003               ubi kayu basah 1 kg     1
# 10  PROD-0000011       KTG-003                    ubi jalar 1 kg     1
# 11  PROD-0000012       KTG-003                       wortel 1 kg     1
# ...

# %% [markdown]
# $$TUGAS$$

# %% [markdown]
# Dalam DataFrame `data` tambahkan kolom `nama produk`

# %%
data_harga['nama produk'] = produk['nama_produk']
data_harga[0:42]
# Out:
#      kode_produk          tgl_berlaku kode_cabang  harga_berlaku_cabang  \
# 0   PROD-0000001  2008-01-01 00:00:00  CABANG-039                 10980
# 1   PROD-0000002  2008-01-01 00:00:00  CABANG-039                  4220
# 2   PROD-0000003  2008-01-01 00:00:00  CABANG-039                  6220
# 3   PROD-0000004  2008-01-01 00:00:00  CABANG-039                  8020
# 4   PROD-0000005  2008-01-01 00:00:00  CABANG-039                  7210
# 5   PROD-0000006  2008-01-01 00:00:00  CABANG-039                  8110
# 6   PROD-0000007  2008-01-01 00:00:00  CABANG-039                  4640
# 7   PROD-0000008  2008-01-01 00:00:00  CABANG-039                  1060
# 8   PROD-0000009  2008-01-01 00:00:00  CABANG-039                  4690
# 9   PROD-0000010  2008-01-01 00:00:00  CABANG-039                  1100
# 10  PROD-0000011  2008-01-01 00:00:00  CABANG-039                  1210
# 11  PROD-0000012  2008-01-01 00:00:00  CABANG-039                  3440
# ...

# %%
# jumlah seluruh harga yang berlaku
data_harga.loc[(data_harga['kode_produk'] >= "PROD-0000001") & (data_harga['kode_produk'] <= "PROD-0000041"), 'harga_berlaku_cabang'].sum()
# Out:
# 635856680

# %% [markdown]
# Buat DataFrame `jumlah_produk` yang menunjukan jumlah produk 1 sampai 41 beserta total harga

# %%
result = []
for i in range(1, 41):
    kode_produk = f"PROD-00000{1:02d}"
    total_harga = sum(data_harga[(data_harga['kode_produk'] == kode_produk)]['harga_berlaku_cabang'])
    result.append({'kode_produk': kode_produk, 'total_harga': total_harga})

df = pd.DataFrame(result)
print(df)

data_harga['total'] = df['total_harga']
data_harga.head(42)
# Out:
#      kode_produk  total_harga
# 0   PROD-0000001     12723420
# 1   PROD-0000001     12723420
# 2   PROD-0000001     12723420
# 3   PROD-0000001     12723420
# 4   PROD-0000001     12723420
# 5   PROD-0000001     12723420
# 6   PROD-0000001     12723420
# 7   PROD-0000001     12723420
# 8   PROD-0000001     12723420
# 9   PROD-0000001     12723420
# 10  PROD-0000001     12723420
# 11  PROD-0000001     12723420
# 12  PROD-0000001     12723420
# 13  PROD-0000001     12723420
# 14  PROD-0000001     12723420
# 15  PROD-0000001     12723420
# 16  PROD-0000001     12723420
# 17  PROD-0000001     12723420
# 18  PROD-0000001     12723420
# 19  PROD-0000001     12723420
# 20  PROD-0000001     12723420
# 21  PROD-0000001     12723420
# 22  PROD-0000001     12723420
# 23  PROD-0000001     12723420
# 24  PROD-0000001     12723420
# 25  PROD-0000001     12723420
# 26  PROD-0000001     12723420
# 27  PROD-0000001     12723420
# 28  PROD-0000001     12723420
# 29  PROD-0000001     12723420
# ...

# %%
results = []
for i in range(1, 4):
    kode_produk = f"PROD-00000{1:02d}"
    total_harga = len(data_harga[(data_harga['kode_produk'] == kode_produk)])
    results.append({'kode_produk': kode_produk, 'total_produk': total_harga})

df = pd.DataFrame(results)
print(df)

data_harga['jumlah_produk'] = df['total_produk']
data_harga.head(42)
# Out:
#     kode_produk  total_produk
# 0  PROD-0000001          1098
# 1  PROD-0000001          1098
# 2  PROD-0000001          1098
#      kode_produk          tgl_berlaku kode_cabang  harga_berlaku_cabang  \
# 0   PROD-0000001  2008-01-01 00:00:00  CABANG-039                 10980
# 1   PROD-0000002  2008-01-01 00:00:00  CABANG-039                  4220
# 2   PROD-0000003  2008-01-01 00:00:00  CABANG-039                  6220
# 3   PROD-0000004  2008-01-01 00:00:00  CABANG-039                  8020
# 4   PROD-0000005  2008-01-01 00:00:00  CABANG-039                  7210
# 5   PROD-0000006  2008-01-01 00:00:00  CABANG-039                  8110
# 6   PROD-0000007  2008-01-01 00:00:00  CABANG-039                  4640
# 7   PROD-0000008  2008-01-01 00:00:00  CABANG-039                  1060
# 8   PROD-0000009  2008-01-01 00:00:00  CABANG-039                  4690
# 9   PROD-0000010  2008-01-01 00:00:00  CABANG-039                  1100
# ...
